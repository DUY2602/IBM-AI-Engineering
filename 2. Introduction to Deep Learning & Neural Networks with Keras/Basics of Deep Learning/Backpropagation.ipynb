# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork/images/IDSN-logo.png" width="400"> </a>
#
# # BackPropagation
#
# Estimated time needed: **30** mins

# %% [markdown]
# Backpropagation is the key algorithm used for training neural networks, allowing them to learn from data. It is based on the gradient descent optimization technique and works by iteratively adjusting the weights and biases of the network to minimize the error between the predicted and actual outputs.
#  In this lab, we will create a neural network to implement backpropagation for a XOR problem.

# %% [markdown]
# # Objective for this notebook
#
# * Train a Neural Network to Solve the XOR Problem
# * Implement Backpropagation for Neural Network Training
# * Demonstrate the Use of Activation Functions
# * Understand the Learning Process Over Multiple Epochs
# * Demonstrate Weight and Bias Adjustments via Gradient Descent
# * Evaluate the Model's Performance After Training
# * Monitor and Analyze the Training Process

# %% [markdown]
# <h2>Table of Contents</h2>
#
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 4>
# 1. <a href="#Import-Required-Libraries">Import Required Libraries</a><br>
# 2. <a href="#Initialize-Inputs">Initialize Inputs</a><br>
# 3. <a href="#Declare-the-network-parameters">Declare the network parameters</a><br>
# 4. <a href="#Define-the-weights">Define the weights</a><br>
# 5. <a href="#Training-the-Neural-Network">Training the Neural Network</a><br>
# 6. <a href="#Testing-the-Network">Testing the Network</a><br>
# 7. <a href="#Plot-the-error">Plot the error</a><br>
#
# </font>
# </div>

# %% [markdown]
# ## Import Required Libraries

# %%
# Importing the required library
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Initialize Inputs
# Define the input and expected output for a XOR gate problem

# %%
# Defining inputs and expected output (XOR truth table)
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]]).T  # 2x4 matrix, each column is a training example
d_xor = np.array([0, 1, 1, 0])  # Expected output for XOR

# %% [markdown]
# # Declare the network parameters & the weights
#
# Define the network parameters such as
# 1. number of input neurons
# 2. hidden layer neurons
# 3. output neurons
# 4. learning rate
# 5. number of epochs
#
# Also, Declare the weights for the neurons. The initial weights are taken as random numbers which are then optimized by the backpropagation algorithm inside a function parameter `initialize_network_parameters()`

# %%
def initialize_network_parameters():
    # Network parameters
    inputSize = 2      # Number of input neurons (x1, x2)
    hiddenSize = 2     # Number of hidden neurons
    outputSize = 1     # Number of output neurons

    # Initialize weights and biases randomly within the range [-1, 1]
    w1 = np.random.rand(hiddenSize, inputSize) * 2 - 1  # Weights from input to hidden layer
    b1 = np.random.rand(hiddenSize, 1) * 2 - 1          # Bias for hidden layer
    w2 = np.random.rand(outputSize, hiddenSize) * 2 - 1 # Weights from hidden to output layer
    b2 = np.random.rand(outputSize, 1) * 2 - 1          # Bias for output layer

    return w1, b1, w2, b2

# %% [markdown]
# ## Training the Neural Network
#
# The neural network works in 5 stages:
# 1. Forward pass
#     * The input **X** is multiplied by the weights **w1** and passed through the first layer, followed by the application of the sigmoid or ReLU activation function. This gives the output for the hidden layer.
#     * The output of the hidden layer is then passed through the second set of weights **w2** to compute the final output. Again, a sigmoid activation function is used to generate the final output **a2**.
#
# 2. Error calculation
#     * The error is computed as the difference between the expected output **(d)** and the actual output **(a2)**.
# 3. Backward pass
#     * **Output Layer**: The derivative of the sigmoid activation function is applied to the error, producing the gradient for the output layer **(da2)**. This is used to calculate how much the weights in the output layer need to be adjusted.
#     * **Hidden Layer**: The error is then propagated backward to the hidden layer. The gradient at the hidden layer **(da1)** is computed by taking the dot product of the transpose of the weights **(w2.T)** and the gradient from the output layer. The derivative of the activation function (sigmoid or ReLU) is used to adjust this error.
# 4. Weights and bias updates
#     * After computing the **gradients (dz1, dz2)**, the **weights (w1, w2)** and **biases (b1, b2)** are updated using the **learning rate (lr)** and **the gradients**. The updates are done to minimize the error and improve the model’s predictions.
# 5. Training:
#     * This entire process is repeated over many iterations **(epochs)**. During each epoch, the model adjusts its weights and biases to reduce the error. Over time, the network learns to approximate the XOR function.
# Forward Pass:

# %%
def backpropagation(X, d, lr, epochs):
    # Get initialized parameters
    w1, b1, w2, b2 = initialize_network_parameters()

    # Training the network using backpropagation
    error_list = []
    for epoch in range(epochs):
        # ==========Forward pass==========
        # Hidden Layer
        z1 = np.dot(w1, X) + b1  # Weighted sum
        a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation

        # Output Layer
        z2 = np.dot(w2, a1) + b2  # Weighted sum
        a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation

        # ==========Backward pass (Backpropagation)==========
        # Output Layer
        error = d - a2  # Difference between target & prediction
        da2 = error * (a2 * (1 - a2))  # Error multiplied by sigmoid derivative
        dz2 = da2  # Gradient for output layer

        # Propagate error to Hidden Layer
        da1 = np.dot(w2.T, dz2)  # Gradient
        dz1 = da1 * (a1 * (1 - a1))  # Derivative

        # ==========Update weights and biases==========
        # Output Layer
        w2 += lr * np.dot(dz2, a1.T)  # Update weights
        b2 += lr * np.sum(dz2, axis=1, keepdims=True)  # Update bias

        # Hidden Layer
        w1 += lr * np.dot(dz1, X.T)  # Update weights
        b1 += lr * np.sum(dz1, axis=1, keepdims=True)  # Update bias

        # Training report
        if (epoch+1)%10000 == 0:
            print("Epoch: %d, Average error: %0.05f"%(epoch, np.average(abs(error))))
            error_list.append(np.average(abs(error)))

    return error_list, w1, b1, w2, b2, error

# %% [markdown]
# ## Testing the Network
# After training, you can now test the neural network to verify that it has learned the XOR function and outputs the correct values close to [0, 1, 1, 0]

# %%
lr = 0.1           # Learning rate
epochs = 180000    # Number of training epochs

# Testing the trained network
error_list, w1, b1, w2, b2, error = backpropagation(X, d_xor, lr, epochs)

# Hidden Layer
z1 = np.dot(w1, X) + b1  # Weighted sum
a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation

# Output Layer
z2 = np.dot(w2, a1) + b2  # Weighted sum
a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation

# Print results
print('Final output after training:', a2)
print('Ground truth', d_xor)
print('Error after training:', error)
print('Average error: %0.05f'%np.average(abs(error)))
# Out:
# Epoch: 9999, Average error: 0.04873
# Epoch: 19999, Average error: 0.02929
# Epoch: 29999, Average error: 0.02268
# Epoch: 39999, Average error: 0.01911
# Epoch: 49999, Average error: 0.01680
# Epoch: 59999, Average error: 0.01515
# Epoch: 69999, Average error: 0.01390
# Epoch: 79999, Average error: 0.01292
# Epoch: 89999, Average error: 0.01211
# Epoch: 99999, Average error: 0.01144
# Epoch: 109999, Average error: 0.01086
# Epoch: 119999, Average error: 0.01037
# Epoch: 129999, Average error: 0.00993
# Epoch: 139999, Average error: 0.00954
# Epoch: 149999, Average error: 0.00920
# Epoch: 159999, Average error: 0.00889
# Epoch: 169999, Average error: 0.00861
# Epoch: 179999, Average error: 0.00835
# Final output after training: [[0.00839508 0.99039666 0.99207331 0.00748733]]
# Ground truth [0 1 1 0]
# Error after training: [[-0.0083951   0.00960337  0.00792671 -0.00748735]]
# Average error: 0.00835

# %% [markdown]
# ## Plot the error
# Here, we plot the error as a function of epochs. This shows how error changed over multiple iterations of forward and backward passes and how the network learnt over time

# %%
# Plot error
plt.plot(error_list)
plt.title('Error')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.show()

# %% [markdown]
# # Practice exercise 1

# %% [markdown]
# Implement backpropagation for **AND problem** using similar input as used for XOR problem above and plot the error

# %%
# Write your code here
d_and = [1, 0, 1, 0]
error_list, w1, b1, w2, b2, error = backpropagation(X, d_and, lr, epochs)

# Plot error
plt.plot(error_list)
plt.title('Error')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.show()
# Out:
# Epoch: 9999, Average error: 0.01942
# Epoch: 19999, Average error: 0.01306
# Epoch: 29999, Average error: 0.01043
# Epoch: 39999, Average error: 0.00892
# Epoch: 49999, Average error: 0.00791
# Epoch: 59999, Average error: 0.00717
# Epoch: 69999, Average error: 0.00661
# Epoch: 79999, Average error: 0.00615
# Epoch: 89999, Average error: 0.00578
# Epoch: 99999, Average error: 0.00547
# Epoch: 109999, Average error: 0.00520
# Epoch: 119999, Average error: 0.00497
# Epoch: 129999, Average error: 0.00476
# Epoch: 139999, Average error: 0.00458
# Epoch: 149999, Average error: 0.00442
# Epoch: 159999, Average error: 0.00427
# Epoch: 169999, Average error: 0.00414
# Epoch: 179999, Average error: 0.00402

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
#
#
# X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]]).T  # 2x4 matrix, each column is a training example
# d = np.array([0, 0, 0, 1])  # Expected output for AND
#
# # Get initialized parameters
# w1, b1, w2, b2, lr, epochs = initialize_network_parameters()
#
# # Training the network using backpropagation
# error_list = []
# for epoch in range(epochs):
#     # Forward pass
#     z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
#     a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer
#
#     z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
#     a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer
#
#     # Error calculation and backpropagation
#     error = d - a2  # Difference between expected and actual output
#     da2 = error * (a2 * (1 - a2))  # Derivative for output layer
#     dz2 = da2  # Gradient for output layer
#
#     # Propagate error to hidden layer
#     da1 = np.dot(w2.T, dz2)  # Gradient for hidden layer
#     dz1 = da1 * (a1 * (1 - a1))  # Derivative for hidden layer
#
#     # Update weights and biases
#     w2 += lr * np.dot(dz2, a1.T)  # Update weights from hidden to output layer
#     b2 += lr * np.sum(dz2, axis=1, keepdims=True)  # Update bias for output layer
#
#     w1 += lr * np.dot(dz1, X.T)  # Update weights from input to hidden layer
#     b1 += lr * np.sum(dz1, axis=1, keepdims=True)  # Update bias for hidden layer
#     if (epoch+1)%10000 == 0:
#         print("Epoch: %d, Average error: %0.05f"%(epoch, np.average(abs(error))))
#         error_list.append(np.average(abs(error)))
#
#
# # Testing the trained network
# z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
# a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer
#
# z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
# a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer
#
# # Print results
# print('\nFinal output after training:', a2)
# print('Ground truth', d)
# print('Error after training:', error)
# print('Average error: %0.05f'%np.average(abs(error)))
#
# # Plot error
# plt.plot(error_list)
# plt.title('Error')
# plt.xlabel('Epochs')
# plt.ylabel('Error')
# plt.show()
#
#
# -->

# %% [markdown]
# # Practice exercise 2

# %% [markdown]
# Now, decrease the learning rate to 0.01 and increase the number of epochs to 1000000 and check the error for XOR gate

# %%
lr = 0.01
epochs = 1000000

error_list, w1, b1, w2, b2, error = backpropagation(X, d_xor, lr, epochs)

# Plot error
plt.plot(error_list)
plt.title('Error')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.show()
# Out:
# Epoch: 9999, Average error: 0.48742
# Epoch: 19999, Average error: 0.44319
# Epoch: 29999, Average error: 0.39767
# Epoch: 39999, Average error: 0.37598
# Epoch: 49999, Average error: 0.35805
# Epoch: 59999, Average error: 0.27829
# Epoch: 69999, Average error: 0.17750
# Epoch: 79999, Average error: 0.13009
# Epoch: 89999, Average error: 0.10516
# Epoch: 99999, Average error: 0.08978
# Epoch: 109999, Average error: 0.07925
# Epoch: 119999, Average error: 0.07152
# Epoch: 129999, Average error: 0.06557
# Epoch: 139999, Average error: 0.06082
# Epoch: 149999, Average error: 0.05692
# Epoch: 159999, Average error: 0.05366
# Epoch: 169999, Average error: 0.05087
# Epoch: 179999, Average error: 0.04845
# Epoch: 189999, Average error: 0.04634
# Epoch: 199999, Average error: 0.04447
# Epoch: 209999, Average error: 0.04280
# Epoch: 219999, Average error: 0.04130
# Epoch: 229999, Average error: 0.03994
# Epoch: 239999, Average error: 0.03870
# Epoch: 249999, Average error: 0.03756
# Epoch: 259999, Average error: 0.03652
# Epoch: 269999, Average error: 0.03555
# Epoch: 279999, Average error: 0.03466
# Epoch: 289999, Average error: 0.03383
# Epoch: 299999, Average error: 0.03305
# Epoch: 309999, Average error: 0.03232
# Epoch: 319999, Average error: 0.03164
# Epoch: 329999, Average error: 0.03099
# Epoch: 339999, Average error: 0.03039
# Epoch: 349999, Average error: 0.02981
# Epoch: 359999, Average error: 0.02927
# Epoch: 369999, Average error: 0.02876
# Epoch: 379999, Average error: 0.02827
# Epoch: 389999, Average error: 0.02780
# Epoch: 399999, Average error: 0.02735
# Epoch: 409999, Average error: 0.02693
# Epoch: 419999, Average error: 0.02652
# Epoch: 429999, Average error: 0.02614
# Epoch: 439999, Average error: 0.02576
# Epoch: 449999, Average error: 0.02541
# Epoch: 459999, Average error: 0.02506
# Epoch: 469999, Average error: 0.02473
# Epoch: 479999, Average error: 0.02441
# Epoch: 489999, Average error: 0.02411
# Epoch: 499999, Average error: 0.02381
# Epoch: 509999, Average error: 0.02353
# Epoch: 519999, Average error: 0.02325
# Epoch: 529999, Average error: 0.02299
# Epoch: 539999, Average error: 0.02273
# Epoch: 549999, Average error: 0.02248
# Epoch: 559999, Average error: 0.02224
# Epoch: 569999, Average error: 0.02201
# Epoch: 579999, Average error: 0.02178
# Epoch: 589999, Average error: 0.02156
# Epoch: 599999, Average error: 0.02135
# Epoch: 609999, Average error: 0.02114
# Epoch: 619999, Average error: 0.02094
# Epoch: 629999, Average error: 0.02074
# Epoch: 639999, Average error: 0.02055
# Epoch: 649999, Average error: 0.02036
# Epoch: 659999, Average error: 0.02018
# Epoch: 669999, Average error: 0.02001
# Epoch: 679999, Average error: 0.01983
# Epoch: 689999, Average error: 0.01967
# Epoch: 699999, Average error: 0.01950
# Epoch: 709999, Average error: 0.01934
# Epoch: 719999, Average error: 0.01919
# Epoch: 729999, Average error: 0.01903
# Epoch: 739999, Average error: 0.01889
# Epoch: 749999, Average error: 0.01874
# Epoch: 759999, Average error: 0.01860
# Epoch: 769999, Average error: 0.01846
# Epoch: 779999, Average error: 0.01832
# Epoch: 789999, Average error: 0.01819
# Epoch: 799999, Average error: 0.01806
# Epoch: 809999, Average error: 0.01793
# Epoch: 819999, Average error: 0.01781
# Epoch: 829999, Average error: 0.01768
# Epoch: 839999, Average error: 0.01756
# Epoch: 849999, Average error: 0.01745
# Epoch: 859999, Average error: 0.01733
# Epoch: 869999, Average error: 0.01722
# Epoch: 879999, Average error: 0.01711
# Epoch: 889999, Average error: 0.01700
# Epoch: 899999, Average error: 0.01689
# Epoch: 909999, Average error: 0.01679
# Epoch: 919999, Average error: 0.01668
# Epoch: 929999, Average error: 0.01658
# Epoch: 939999, Average error: 0.01648
# Epoch: 949999, Average error: 0.01639
# Epoch: 959999, Average error: 0.01629
# Epoch: 969999, Average error: 0.01619
# Epoch: 979999, Average error: 0.01610
# Epoch: 989999, Average error: 0.01601
# Epoch: 999999, Average error: 0.01592

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
#
# lr = 0.01         # Learning rate
# epochs = 1000000   # Number of training epochs
#
#
# # Defining inputs and expected output (XOR truth table)
# X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]]).T  # 2x4 matrix, each column is a training example
# d = np.array([0, 1, 1, 0])  # Expected output for XOR
#
# # Get initialized parameters
# w1, b1, w2, b2, lr, epochs = initialize_network_parameters()
#
# # Training the network using backpropagation
# error_list = []
# for epoch in range(epochs):
#     # Forward pass
#     z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
#     a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer
#
#     z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
#     a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer
#
#     # Error calculation and backpropagation
#     error = d - a2  # Difference between expected and actual output
#     da2 = error * (a2 * (1 - a2))  # Derivative for output layer
#     dz2 = da2  # Gradient for output layer
#
#     # Propagate error to hidden layer
#     da1 = np.dot(w2.T, dz2)  # Gradient for hidden layer
#     dz1 = da1 * (a1 * (1 - a1))  # Derivative for hidden layer
#
#     # Update weights and biases
#     w2 += lr * np.dot(dz2, a1.T)  # Update weights from hidden to output layer
#     b2 += lr * np.sum(dz2, axis=1, keepdims=True)  # Update bias for output layer
#
#     w1 += lr * np.dot(dz1, X.T)  # Update weights from input to hidden layer
#     b1 += lr * np.sum(dz1, axis=1, keepdims=True)  # Update bias for hidden layer
#     if (epoch+1)%10000 == 0:
#         print("Epoch: %d, Average error: %0.05f"%(epoch, np.average(abs(error))))
#         error_list.append(np.average(abs(error)))
#
#
# # Testing the trained network
# z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
# a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer
#
# z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
# a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer
#
# # Print results
# print('\nFinal output after training:', a2)
# print('Ground truth', d)
# print('Error after training:', error)
# print('Average error: %0.05f'%np.average(abs(error)))
#
#
# # Plot error
# plt.plot(error_list)
# plt.title('Error')
# plt.xlabel('Epochs')
# plt.ylabel('Error')
# plt.show()
#
#
# -->
